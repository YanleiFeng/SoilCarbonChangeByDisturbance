# %%
import pandas as pd
eventtype = pd.read_csv('/Users/yanlei/Documents/PhD/postdoc_3B/NEON_download/eventType.csv')
events = eventtype["eventType"].unique()
print(events)
# Out:
# ['populationSpike' 'otherNaturalDisturbance' 'plantReduction'
#  'chemicalApplication' 'humanDisturbance' 'obstruction' 'other'
#  'ownershipChange' 'wildlifeDisturbance' 'fire' 'grazing'
#  'morphologyChange' 'plantAddition' 'iceOn' 'droughtPerceived'
#  'animalReduction' 'tillage' 'irrigation' 'biocontrol' 'pollutant']

# %%
event_PopSpi = eventtype[eventtype["eventType"] == "grazing"]

# %%
event_PopSpi.to_csv("/Users/yanlei/Documents/PhD/postdoc_3B/NEON_download/grazing.csv")

# %%
sites_ps = eventtype[eventtype["eventType"] == "animalReduction"]["siteID"].unique()
sites_ps
# Out:
# array(['DSNY', 'JERC', 'MCDI', 'PRLA', 'PRPO', 'PUUM', 'SCBI'],
#       dtype=object)

# %%
sim_slsChemistryData = pd.read_csv('/Users/yanlei/Documents/PhD/postdoc_3B/NEON_download/sls_chemistry.csv')

# %%
slsChemistry_specific_disturbance = sim_slsChemistryData[sim_slsChemistryData["siteID"].isin(sites_ps)]
slsChemistry_specific_disturbance
# Out:
#       Unnamed: 0                                   uid analysisDate  \
# 917          917  aceb8755-1558-423c-a06a-67e2512ff364   2015-01-15
# 918          918  bfe2bcde-7570-4de1-aede-8b5b86a24e09   2015-01-15
# 919          919  bad1fa61-714d-4a73-9f18-3cc4c7c27e91   2015-01-15
# 920          920  d254b091-8a00-47b1-98b7-d0e9dc670d92   2015-01-15
# 921          921  38817d98-32d4-4393-a9ea-7919b14b84e9   2015-01-15
# ...          ...                                   ...          ...
# 3320        3320  2e16dc6e-fba1-4368-8218-41aa6ead8a3e   2022-10-13
# 3321        3321  7d76f520-94db-4ca5-8fbf-2f632cdc80e8   2022-10-13
# 3322        3322  1afdb0b9-f769-4a5d-a16f-cab2efd1e3b2   2022-10-13
# 3323        3323  87106e0c-67ac-4958-84e3-ec214545ef91   2022-10-13
# 3324        3324  02d1afd1-8bab-4457-8100-e2a8d6c4fc3d   2022-10-13
#
#               namedLocation domainID siteID    plotID     plotType  \
# 917   DSNY_041.basePlot.bgc      D03   DSNY  DSNY_041        tower
# 918   DSNY_041.basePlot.bgc      D03   DSNY  DSNY_041        tower
# 919   DSNY_005.basePlot.bgc      D03   DSNY  DSNY_005  distributed
# 920   DSNY_041.basePlot.bgc      D03   DSNY  DSNY_041        tower
# 921   DSNY_003.basePlot.bgc      D03   DSNY  DSNY_003  distributed
# ...                     ...      ...    ...       ...          ...
# 3320  SCBI_049.basePlot.bgc      D02   SCBI  SCBI_049        tower
# 3321  SCBI_049.basePlot.bgc      D02   SCBI  SCBI_049        tower
# 3322  SCBI_045.basePlot.bgc      D02   SCBI  SCBI_045        tower
# 3323  SCBI_045.basePlot.bgc      D02   SCBI  SCBI_045        tower
# 3324  SCBI_045.basePlot.bgc      D02   SCBI  SCBI_045        tower
#
#               startDate        collectDate  ... analyticalRepNumber  \
# 917   2014-01-22T17:00Z  2014-01-22T17:00Z  ...                 1.0
# 918   2014-02-27T17:00Z  2014-02-27T17:00Z  ...                 1.0
# 919   2014-05-15T16:00Z  2014-05-15T16:00Z  ...                 1.0
# 920   2014-06-03T16:00Z  2014-06-03T16:00Z  ...                 1.0
# 921   2014-08-13T16:00Z  2014-08-13T16:00Z  ...                 1.0
# ...                 ...                ...  ...                 ...
# 3320  2022-07-13T14:30Z  2022-07-13T14:30Z  ...                 1.0
# 3321  2022-07-13T14:50Z  2022-07-13T14:50Z  ...                 1.0
# 3322  2022-07-13T15:29Z  2022-07-13T15:29Z  ...                 1.0
# 3323  2022-07-13T15:59Z  2022-07-13T15:59Z  ...                 1.0
# 3324  2022-07-13T16:30Z  2022-07-13T16:30Z  ...                 1.0
#
#                  remarks                                 laboratoryName  \
# 917                  NaN  University of Wyoming Stable Isotope Facility
# 918                  NaN  University of Wyoming Stable Isotope Facility
# 919                  NaN  University of Wyoming Stable Isotope Facility
# 920                  NaN  University of Wyoming Stable Isotope Facility
# 921   Replicate samples.  University of Wyoming Stable Isotope Facility
# ...                  ...                                            ...
# 3320                 NaN  University of Wyoming Stable Isotope Facility
# 3321                 NaN  University of Wyoming Stable Isotope Facility
# 3322                 NaN  University of Wyoming Stable Isotope Facility
# 3323                 NaN  University of Wyoming Stable Isotope Facility
# 3324                 NaN  University of Wyoming Stable Isotope Facility
#
#                                    testMethod  \
# 917   010 EA-IRMS organic d15n, d13c, C% & N%
# 918   010 EA-IRMS organic d15n, d13c, C% & N%
# 919   010 EA-IRMS organic d15n, d13c, C% & N%
# 920   010 EA-IRMS organic d15n, d13c, C% & N%
# 921   010 EA-IRMS organic d15n, d13c, C% & N%
# ...                                       ...
# 3320  010 EA-IRMS organic d15N, d13C, C% & N%
# 3321  010 EA-IRMS organic d15N, d13C, C% & N%
# 3322  010 EA-IRMS organic d15N, d13C, C% & N%
# 3323  010 EA-IRMS organic d15N, d13C, C% & N%
# 3324  010 EA-IRMS organic d15N, d13C, C% & N%
#
#                                              instrument  \
# 917                                                 NaN
# 918                                                 NaN
# 919                                                 NaN
# 920                                                 NaN
# 921                                                 NaN
# ...                                                 ...
# 3320  Costech 4010 Elemental Analyzer with Costech Z...
# 3321  Costech 4010 Elemental Analyzer with Costech Z...
# 3322  Costech 4010 Elemental Analyzer with Costech Z...
# 3323  Costech 4010 Elemental Analyzer with Costech Z...
# 3324  Costech 4010 Elemental Analyzer with Costech Z...
#
#                             analyzedBy                reviewedBy      dataQF  \
# 917   rHBrhUbTwVSLtfc5tc9S18/eJGkjVJIj  L/6ZjMlRllRQ+sQbi+7sFw==  legacyData
# 918   rHBrhUbTwVSLtfc5tc9S18/eJGkjVJIj  L/6ZjMlRllRQ+sQbi+7sFw==  legacyData
# 919   rHBrhUbTwVSLtfc5tc9S18/eJGkjVJIj  L/6ZjMlRllRQ+sQbi+7sFw==  legacyData
# 920   rHBrhUbTwVSLtfc5tc9S18/eJGkjVJIj  L/6ZjMlRllRQ+sQbi+7sFw==  legacyData
# 921   rHBrhUbTwVSLtfc5tc9S18/eJGkjVJIj  L/6ZjMlRllRQ+sQbi+7sFw==  legacyData
# ...                                ...                       ...         ...
# 3320  rHBrhUbTwVSLtfc5tc9S18/eJGkjVJIj  L/6ZjMlRllRQ+sQbi+7sFw==         NaN
# 3321  rHBrhUbTwVSLtfc5tc9S18/eJGkjVJIj  L/6ZjMlRllRQ+sQbi+7sFw==         NaN
# 3322  rHBrhUbTwVSLtfc5tc9S18/eJGkjVJIj  L/6ZjMlRllRQ+sQbi+7sFw==         NaN
# 3323  rHBrhUbTwVSLtfc5tc9S18/eJGkjVJIj  L/6ZjMlRllRQ+sQbi+7sFw==         NaN
# 3324  rHBrhUbTwVSLtfc5tc9S18/eJGkjVJIj  L/6ZjMlRllRQ+sQbi+7sFw==         NaN
#
#        publicationDate       release
# 917   20241118T035922Z  RELEASE-2025
# 918   20241118T025452Z  RELEASE-2025
# 919   20241118T091540Z  RELEASE-2025
# 920   20241118T083333Z  RELEASE-2025
# 921   20241118T005801Z  RELEASE-2025
# ...                ...           ...
# 3320  20241118T132656Z  RELEASE-2025
# 3321  20241118T132656Z  RELEASE-2025
# 3322  20241118T132656Z  RELEASE-2025
# 3323  20241118T132656Z  RELEASE-2025
# 3324  20241118T132656Z  RELEASE-2025
#
# [350 rows x 36 columns]

# %%
slsChemistry_specific_disturbance.to_csv("/Users/yanlei/Documents/PhD/postdoc_3B/NEON_download/slsChemistry_grazing_disturbance.csv")
