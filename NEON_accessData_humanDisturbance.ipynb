# %%
import pandas as pd
eventtype = pd.read_csv('/Users/yanlei/Documents/PhD/postdoc_3B/NEON_download/eventType.csv')
events = eventtype["eventType"].unique()
print(events)
# Out:
# ['populationSpike' 'otherNaturalDisturbance' 'plantReduction'
#  'chemicalApplication' 'humanDisturbance' 'obstruction' 'other'
#  'ownershipChange' 'wildlifeDisturbance' 'fire' 'grazing'
#  'morphologyChange' 'plantAddition' 'iceOn' 'droughtPerceived'
#  'animalReduction' 'tillage' 'irrigation' 'biocontrol' 'pollutant']

# %%
event_spe = eventtype[eventtype["eventType"] == "humanDisturbance"]

# %%
event_spe.to_csv("/Users/yanlei/Documents/PhD/postdoc_3B/NEON_download/humanDisturbance.csv")

# %%
sites_sp = eventtype[eventtype["eventType"] == "humanDisturbance"]["siteID"].unique()
sites_sp
# Out:
# array(['ABBY', 'ARIK', 'BARR', 'BART', 'BIGC', 'BLUE', 'CARI', 'CLBJ',
#        'COMO', 'CUPE', 'DCFS', 'DSNY', 'FLNT', 'GUIL', 'HEAL', 'HOPB',
#        'JERC', 'KING', 'LAJA', 'LEWI', 'MLBS', 'NOGP', 'OAES', 'ORNL',
#        'OSBS', 'POSE', 'PUUM', 'RMNP', 'SCBI', 'SERC', 'SOAP', 'STEI',
#        'SYCA', 'TALL', 'TREE', 'WLOU', 'YELL'], dtype=object)

# %%
sim_slsChemistryData = pd.read_csv('/Users/yanlei/Documents/PhD/postdoc_3B/NEON_download/sls_chemistry.csv')

# %%
slsChemistry_popSpi_disturbance = sim_slsChemistryData[sim_slsChemistryData["siteID"].isin(sites_sp)]
slsChemistry_popSpi_disturbance
# Out:
#       Unnamed: 0                                   uid analysisDate  \
# 0              0  cc4d4f6a-d5ba-446b-ad84-aa5e75b193eb   2022-09-26
# 1              1  6242af4c-1d1e-4182-bd19-87f674ec2ccd   2022-09-26
# 2              2  7f733f1b-899a-4ac4-b899-fb3bf7da78ba   2022-09-26
# 3              3  83ac56e5-963a-4c79-af55-33fe1d29f3a8   2022-10-05
# 4              4  d440b5fd-cec4-487b-b2a4-78d3b39831f9   2022-09-26
# ...          ...                                   ...          ...
# 4740        4740  49de9512-23c4-40ab-9530-9dd3b94ab11a   2024-01-04
# 4741        4741  926c6d29-e564-419a-903c-e0e4e74fa43f   2024-01-04
# 4742        4742  b02bea71-1596-4b2e-ac25-a5895beb042b   2024-01-09
# 4743        4743  73b4f76d-ab5f-4c0e-957a-1d81b7fab354   2024-01-04
# 4744        4744  68a6a4eb-fa74-4719-a7ca-6f0f1f865aec   2024-01-09
#
#               namedLocation domainID siteID    plotID     plotType  \
# 0     ABBY_063.basePlot.bgc      D16   ABBY  ABBY_063        tower
# ...

# %%
slsChemistry_popSpi_disturbance.to_csv("/Users/yanlei/Documents/PhD/postdoc_3B/NEON_download/slsChemistry_humanDisturbance_disturbance.csv")
