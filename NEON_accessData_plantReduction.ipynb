# %%
import pandas as pd
eventtype = pd.read_csv('/Users/yanlei/Documents/PhD/postdoc_3B/NEON_download/eventType.csv')
events = eventtype["eventType"].unique()

# %%
event_PopSpi = eventtype[eventtype["eventType"] == "populationSpike"]

# %%
event_PopSpi.to_csv("/Users/yanlei/Documents/PhD/postdoc_3B/NEON_download/populationSpike.csv")

# %%
sites_ps = eventtype[eventtype["eventType"] == "populationSpike"]["siteID"].unique()
sites_ps
# Out:
# array(['ABBY', 'DSNY', 'HARV', 'JERC', 'MCRA', 'OSBS', 'REDB', 'SYCA'],
#       dtype=object)

# %%
sim_slsChemistryData = pd.read_csv('/Users/yanlei/Documents/PhD/postdoc_3B/NEON_download/sls_chemistry.csv')

# %%
slsChemistry_popSpi_disturbance = sim_slsChemistryData[sim_slsChemistryData["siteID"].isin(sites_ps)]
slsChemistry_popSpi_disturbance
# Out:
#       Unnamed: 0                                   uid analysisDate  \
# 0              0  cc4d4f6a-d5ba-446b-ad84-aa5e75b193eb   2022-09-26
# 1              1  6242af4c-1d1e-4182-bd19-87f674ec2ccd   2022-09-26
# 2              2  7f733f1b-899a-4ac4-b899-fb3bf7da78ba   2022-09-26
# 3              3  83ac56e5-963a-4c79-af55-33fe1d29f3a8   2022-10-05
# 4              4  d440b5fd-cec4-487b-b2a4-78d3b39831f9   2022-09-26
# ...          ...                                   ...          ...
# 3095        3095  d088b0b9-b0e9-4474-99ca-3a421a3917d4   2022-02-01
# 3096        3096  0cd718a3-9cd3-4154-939a-268bd359828a   2022-01-24
# 3097        3097  5ca051e5-7f30-41cd-9f33-23110f5f107b   2022-01-24
# 3098        3098  17184b0e-df84-4fc2-a502-3ef342e40fd1   2022-01-24
# 3099        3099  f4dcafc5-51d1-43f5-af4b-f3ddaf100a21   2022-01-24
#
#               namedLocation domainID siteID    plotID     plotType  \
# 0     ABBY_063.basePlot.bgc      D16   ABBY  ABBY_063        tower
# ...

# %%
slsChemistry_popSpi_disturbance.to_csv("/Users/yanlei/Documents/PhD/postdoc_3B/NEON_download/slsChemistry_popSpi_disturbance.csv")
